# %% [markdown]
# **1.IMPORT LIBRARIES**

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# **2.CREATING A SYNTHETIC PURCHASE DATASET**

# %%
data = {
    'Annual_Income_k$':[15,16,17,18,19,60,62,63,64,65,100,102,105,110,120],
    'Spending_Score':[39,81,6,77,40,49,55,52,60,45,15,20,10,8,12]
}
df = pd.DataFrame(data)

# %% [markdown]
# **2. Preprocessing: Scaling is crucial for K-Means**
#
# **Since K-Means is distance-based, all features must be on the same scale.**

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
scaled_data = scaler.fit_transform(df)

# %% [markdown]
# **3. Finding the optimal number of clusters (The Elbow Method)**

# %%
from sklearn.cluster import KMeans
wcss = []
for i in range(1, 11):
  kmeans = KMeans(n_clusters=i, init= 'k-means++', random_state=42)
  kmeans.fit(scaled_data)
  wcss.append(kmeans.inertia_)

# %% [markdown]
# **4. Applying K-Means to the dataset**

# %%
kmeans = KMeans(n_clusters=3, init= 'k-means++', random_state=42)
clusters = kmeans.fit_predict(scaled_data)

# %% [markdown]
# **5. Adding the cluster labels back to our dataframe**

# %%
df['Clusters'] = clusters
print(df.head())
# Out:
#    Annual_Income_k$  Spending_Score  Clusters
# 0                15              39         2
# 1                16              81         2
# 2                17               6         2
# 3                18              77         2
# 4                19              40         2
